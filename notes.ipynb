# %%
pip install numpy pandas yfinance
# Out:
# ...
#   Using cached pandas-3.0.0-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached websockets-16.0-cp314-cp314-win_amd64.whl.metadata (7.0 kB)
# ...
#   Using cached cffi-2.0.0-cp314-cp314-win_amd64.whl.metadata (2.6 kB)
# ...
#   Using cached certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# ...

# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
goog = yf.Ticker("GOOG")
google_five_year_history = goog.history(period='5y')
google_five_year_history.columns
google_initial_price = google_five_year_history['Close'].iloc[0]

# %%
# Calculate Log Returns (Preferred in quant finance over simple returns)
# np.log -> Vectorized math function
# shift(1) -> Aligns today's price with yesterday's

np.log(google_five_year_history['Close'] / google_five_year_history['Close'].shift(1))
# Out:
# Date
# 2021-02-16 00:00:00-05:00         NaN
# 2021-02-17 00:00:00-05:00    0.003016
# 2021-02-18 00:00:00-05:00   -0.005234
# 2021-02-19 00:00:00-05:00   -0.007614
# 2021-02-22 00:00:00-05:00   -0.017408
#                                ...
# 2026-02-06 00:00:00-05:00   -0.025153
# 2026-02-09 00:00:00-05:00    0.004015
# 2026-02-10 00:00:00-05:00   -0.017947
# 2026-02-11 00:00:00-05:00   -0.023177
# 2026-02-12 00:00:00-05:00   -0.006315
# Name: Close, Length: 1255, dtype: float64

# %%
# Rolling Window Calculations (The bread and butter of Pandas)
window = 20
google_five_year_history['Close SMA'] = google_five_year_history['Close'].rolling(window=window).mean()       # Simple Moving Average
google_five_year_history['Close Vol'] = google_five_year_history['Close'].std()        # Rolling Volatility

# %%
# Vectorized Z-Score Calculation (NumPy Broadcasting)
# Logic: How many standard deviations is price away from the mean?
google_five_year_history['Close Z Score'] = (google_five_year_history['Close'] - google_five_year_history['Close SMA']) / google_five_year_history['Close Vol']
