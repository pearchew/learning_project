# %% [markdown]
# # Trading Strategy & Backtesting
# **Date:** February 2026
# **Objective:** To implement and backtest trading strategy for a selected stock using Python, Pandas, and Vectorized operations.

# %%
pip install numpy pandas yfinance matplotlib plotly ipython nbformat nbconvert
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (2.0.2)
# Requirement already satisfied: pandas in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (2.3.3)
# Requirement already satisfied: yfinance in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (1.2.0)
# Requirement already satisfied: matplotlib in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: plotly in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (6.5.2)
# Requirement already satisfied: ipython in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (8.18.1)
# Requirement already satisfied: nbformat in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (5.10.4)
# Requirement already satisfied: nbconvert in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (7.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from yfinance) (6.33.5)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: websockets>=13.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: peewee>=3.16.2 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from yfinance) (4.0.0)
# Requirement already satisfied: requests>=2.31 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from yfinance) (4.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: cycler>=0.10 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from plotly) (2.17.0)
# Requirement already satisfied: typing-extensions in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from ipython) (4.15.0)
# Requirement already satisfied: matplotlib-inline in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from ipython) (0.2.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from ipython) (2.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from ipython) (3.0.52)
# Requirement already satisfied: decorator in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from ipython) (5.2.1)
# Requirement already satisfied: exceptiongroup in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from ipython) (1.3.1)
# Requirement already satisfied: stack-data in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: jedi>=0.16 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from ipython) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbconvert) (3.2.0)
# Requirement already satisfied: bleach[css]!=5.0.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbconvert) (6.2.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbconvert) (3.0.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbconvert) (8.7.1)
# Requirement already satisfied: jinja2>=3.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbconvert) (3.1.6)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbconvert) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbconvert) (1.5.1)
# Requirement already satisfied: defusedxml in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: webencodings in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from bleach[css]!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from bleach[css]!=5.0.0->nbconvert) (1.4.0)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.2.25)
# Requirement already satisfied: cffi>=1.12.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: pycparser in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: zipp>=3.20 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=3.6->nbconvert) (3.23.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython) (0.8.6)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat) (0.27.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: referencing>=0.28.4 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from nbclient>=0.5.0->nbconvert) (7.4.9)
# Requirement already satisfied: pyzmq>=23.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (24.0.1)
# Requirement already satisfied: entrypoints in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (0.4)
# Requirement already satisfied: tornado>=6.2 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (1.6.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.6.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->yfinance) (2.6.3)
# Requirement already satisfied: pure-eval in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython) (3.0.1)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import yfinance as yf;
# Out:
# /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# Importing chosen stock data from yfinance

# %%
goog = yf.Ticker("GOOG")
google_five_year_history = goog.history(period='5y')

# %% [markdown]
# ### Distinction between cumulative returns, and log returns
# ##### Cumulative returns (reinvesting)
# For example, if we buy an asset for $100 and see a 10%, 5%, and then −2% return, our asset is worth:
# $$ 100(1.1)(1.05)(0.98)=113.19 $$
# At time T=3 our total return is:
# $$ \frac{113.19}{100} - 1 ≈0.13 $$
#
# ##### Log returns
# where $r_t$ is return sequence e.g. in the multiplicative example above
# $$ z_t =log(1+r_t) = log(\frac{FV}{PV}) $$
# log returns are normally distributed if prices are log normally distributed

# %%
#log returns
google_five_year_history['Log_Ret'] = np.log(google_five_year_history['Close']/ google_five_year_history['Close'].shift(1))

# %% [markdown]
# ### Setting sell/purchase signal 1
# The chosen purchase signal is to buy or sell based on whether there is a deviation from the rolling 20 week SMA.

# %%
# Vectorized Z-Score Calculation (NumPy Broadcasting) -> Logic: How many standard deviations is price away from the mean?
google_five_year_history['Z Score'] = (google_five_year_history['Close'] - google_five_year_history['SMA']) / google_five_year_history['Vol']

# %%
# Strategy: Long (+1) if Z < -1 (Oversold), Short (-1) if Z > 1 (Overbought), else Flat (0)
google_five_year_history['Position'] = np.where(google_five_year_history['Z Score'] < -0.1, 1, 
                 np.where(google_five_year_history['Z Score'] > 0.1, -1, 0))

# %%
# Transaction Costs
transaction_cost = 0.001
google_five_year_history['Trades'] = google_five_year_history['Position'].abs().shift(1)

# %% [markdown]
# ### Establishing baseline returns and returns from strategy
# We then look back at whether this strategy performed well, comparing to if we just held the asset over the 5 year peeriod that we are testing over

# %%
# Look-ahead Bias Prevention: We must shift the position down by 1 day (We make the decision Today based on Today's close, so we earn returns Tomorrow)
google_five_year_history['Strategy_Ret'] = google_five_year_history['Position'].shift(1) * google_five_year_history['Log_Ret'] - google_five_year_history['Trades']*transaction_cost

# Cumulative Returns (Equity Curve)
google_five_year_history['Cum_Ret'] = google_five_year_history['Strategy_Ret'].cumsum().apply(np.exp)

# Drawdown Calculation (Crucial Risk Metric) -> cummax() tracks the highest peak reached so far
running_max = google_five_year_history['Cum_Ret'].cummax()
google_five_year_history['Drawdown'] = (google_five_year_history['Cum_Ret'] - running_max) / running_max

# %% [markdown]
# ### Summary of strategy

# %%
clean_df = google_five_year_history.dropna()

print(f"Final Portfolio Value: {clean_df['Cum_Ret'].iloc[-1]:.4f}")
print(f"Max Drawdown: {clean_df['Drawdown'].min():.2%}")
print(f"Sharpe Ratio: {(clean_df['Strategy_Ret'].mean() / clean_df['Strategy_Ret'].std()) * np.sqrt(252):.2f}")

# Check the first few rows to see the structure
print("\nData Snapshot:")
print(clean_df[['Close', 'SMA', 'Z Score', 'Position']].tail())
# Out:
# Final Portfolio Value: 0.2979
# Max Drawdown: -74.36%
# Sharpe Ratio: -0.95
#
# Data Snapshot:
#                                 Close         SMA   Z Score  Position
# Date
# 2026-02-18 00:00:00-05:00  303.940002  275.016093  0.537560        -1
# 2026-02-19 00:00:00-05:00  303.559998  275.776271  0.516369        -1
# 2026-02-20 00:00:00-05:00  314.899994  276.650113  0.710886        -1
# 2026-02-23 00:00:00-05:00  311.690002  277.521780  0.635027        -1
# 2026-02-24 00:00:00-05:00  310.920013  278.346582  0.605387        -1

# %% [markdown]
# ### Visualisation with MatPlotLib

# %%
import matplotlib.pyplot as plt

# Use a clean style for financial charts
plt.style.use('bmh') 

# Create a figure with 3 rows, sharing the same Date (x-axis)
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 10), sharex=True)

# --- CHART 1: Price vs. Moving Average ---
ax1.plot(clean_df.index, clean_df['Close'], label='Stock Price', color='black', alpha=0.6)
ax1.plot(clean_df.index, clean_df['SMA'], label=f'SMA {window}', color='blue', linestyle='--')
ax1.set_title('Mean Reversion Indicators')
ax1.legend(loc='upper left')

# --- CHART 2: Strategy vs. Buy & Hold (Performance) ---
# Calculate Buy & Hold returns for comparison
buy_and_hold = clean_df['Close'] / clean_df['Close'].iloc[0]

ax2.plot(clean_df.index, clean_df['Cum_Ret'], label='Strategy Equity', color='green', linewidth=2)
ax2.plot(clean_df.index, buy_and_hold, label='Buy & Hold', color='gray', linestyle=':', alpha=0.5)
ax2.set_ylabel('Growth (1.0 = Start)')
ax2.set_title('Cumulative Performance')
ax2.legend(loc='upper left')

# --- CHART 3: Drawdown (The "Underwater" Plot) ---
ax3.plot(clean_df.index, clean_df['Drawdown'], color='red', linewidth=1)
# Fill the area to emphasize the "pain"
ax3.fill_between(clean_df.index, clean_df['Drawdown'], 0, color='red', alpha=0.3)
ax3.set_ylabel('Drawdown %')
ax3.set_title('Risk Profile (Underwater Plot)')
ax3.set_xlabel('Date')

# Formatting to prevent label overlap
plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Extra: displaying as an interactive graph object using plotly

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create a subplot figure with 3 rows
# vertical_spacing=0.05 reduces the gap between charts
fig = make_subplots(rows=3, cols=1, shared_xaxes=True, 
                    vertical_spacing=0.05,
                    subplot_titles=('Price & SMA', 'Cumulative Performance', 'Drawdown Risk'),
                    row_heights=[0.5, 0.3, 0.2]) # Give top chart most space

# CHART 1: Price vs. SMA (Candlestick style often preferred, but line is fine) ---
fig.add_trace(go.Scatter(x=clean_df.index, y=clean_df['Close'], 
                         mode='lines', name='Price', line=dict(color='black')), row=1, col=1)

fig.add_trace(go.Scatter(x=clean_df.index, y=clean_df['SMA'], 
                         mode='lines', name=f'SMA {window}', line=dict(color='blue', dash='dash')), row=1, col=1)

# Highlight Buy/Sell Signals
# Buy Signals (Green Triangles)
buys = clean_df[clean_df['Position'] == 1]
fig.add_trace(go.Scatter(x=buys.index, y=buys['Close'], 
                         mode='markers', name='Buy Signal', 
                         marker=dict(symbol='triangle-up', size=10, color='green')), row=1, col=1)

# Sell Signals (Red Triangles)
sells = clean_df[clean_df['Position'] == -1]
fig.add_trace(go.Scatter(x=sells.index, y=sells['Close'], 
                         mode='markers', name='Sell Signal', 
                         marker=dict(symbol='triangle-down', size=10, color='red')), row=1, col=1)


# CHART 2: Strategy vs. Buy & Hold ---
# Re-calculate Buy & Hold for context
buy_and_hold = clean_df['Close'] / clean_df['Close'].iloc[0]

fig.add_trace(go.Scatter(x=clean_df.index, y=clean_df['Cum_Ret'], 
                         mode='lines', name='Strategy Equity', line=dict(color='green', width=2)), row=2, col=1)

fig.add_trace(go.Scatter(x=clean_df.index, y=buy_and_hold, 
                         mode='lines', name='Buy & Hold', line=dict(color='gray', dash='dot')), row=2, col=1)


# --- CHART 3: Drawdown (The "Underwater" Plot) ---
fig.add_trace(go.Scatter(x=clean_df.index, y=clean_df['Drawdown'], 
                         mode='lines', name='Drawdown', line=dict(color='red', width=1),
                         fill='tozeroy'), row=3, col=1) # fill='tozeroy' fills area to 0 line

# --- FINAL LAYOUT POLISH ---
fig.update_layout(title_text="Mean Reversion Strategy Dashboard",
                  height=900,  # Tall enough to see detail
                  showlegend=True,
                  hovermode="x unified") # Shows all values for a specific date at once

# Hide range slider (often annoying on subplots)
fig.update_xaxes(rangeslider_visible=False)

fig.show(renderer='browser')
